# %%
# Mengatur Transaksi Sedang Berjalan
transaksi ='Y'

# Melakukan Perulangan While Jika Status Transaksinya 'N', Maka Transaksi Selesai
while transaksi != 'N':
  import random # Untuk mendapatkan nomor kursi secara acak

  # Mencetak Menu Aplikasi
  print('Selamat datang di Terminal Bungurasih, silahkan pilih menu untuk melanjutkan')
  list_Menu = ['Jadwal Keberangkatan', 'Pemesanan tiket', 'Panduan refund tiket', 'Customer Service']
  print('1. ', list_Menu[0])
  print('2. ', list_Menu[1])
  print('3. ', list_Menu[2])
  print('4. ', list_Menu[3])
  menu=input("Pilih menu: ")
  
  # Apabila Memilih Menu Nomor 1
  if menu == "1":
    # Menu & Daftar Tiket Aplikasi Penjualan Tiket Bus 
    print('                       APLIKASI PENJUALAN TIKET BUS')
    print('                           TERMINAL BUNGURASIH')
      
    from prettytable import PrettyTable

    table = PrettyTable(['NO','KEBERANGKATAN','KODE TUJUAN','TUJUAN','JAM','HARGA'])
    table.add_row(['1.','SURABAYA','YK','YOGYAKARTA','06.00 - 12.00','Rp.550.000,-'])
    table.add_row(['2.','SURABAYA','JKT','JAKARTA','09.00 - 19.00','Rp.890.000,-'])
    table.add_row(['3.','SURABAYA','MLG','MALANG','05.00 - 08.00','Rp.88.000,-'])
    table.add_row(['4.','SURABAYA','SOC','SOLO','15.00 - 22.00','Rp.450.000,-'])
    table.add_row(['5.','SURABAYA','KD','KEDIRI','10.00 - 15.00','Rp.100.000,-'])
    table.add_row(['6.','SURABAYA','BWI','BANYUWANGI','04.00 - 11.00','Rp.560.000,-'])
    table.add_row(['7.','SURABAYA','BL','BALI','04.00 - 20.00','Rp.990.000,-'])
    table.add_row(['8.','SURABAYA','BR','BLITAR','10.00 - 15.00','Rp.300.000,-'])
    table.add_row(['9.','SURABAYA','BDG','BANDUNG','05.00 - 20.00','Rp.780.000,-'])
    table.add_row(['10.','SURABAYA','MN','MADIUN','09.00 - 12.00','Rp.100.000,-'])

    print(table)
    transaksi = input('Apakah Ingin Kembali ke Menu Awal? [Y/N]: ')
    if transaksi == 'y' or transaksi=='Y':
      transaksi='Y'
      print('-' * 81)
    else:
      transaksi='N'
      print('-' * 81)
      print('Terima Kasih Telah Mengunjungi Aplikasi Kami ^.^') 
      break

  # Apabila Memilih Menu nomor 2
  elif menu == "2":
    print('-' * 81)
    print('                       PEMESANAN TIKET')
    #Input
    pembeli = input('Masukan Nama Pembeli: ')
    no_hp = input('Masukan No. Handphone: ')
    nama_tujuan = input('Masukan Tujuan Keberangkatan: ')
    tgl_berangkat = input('Masukan Tanggal Keberangkatan: ')
    jml_tiket = int(input('Masukan Jumlah Pembelian Tiket: '))

    # Proses
    if nama_tujuan=='YK' or nama_tujuan=='yk' or nama_tujuan=='Yogyakarta' or nama_tujuan=='yogyakarta' or nama_tujuan=='YOGYAKARTA':
      nama_tujuan ='Yogyakarta'
      harga = 550000
    elif nama_tujuan=='JKT' or nama_tujuan=='jkt' or nama_tujuan=='Jakarta' or nama_tujuan=='jakarta' or nama_tujuan=='JAKARTA':
      nama_tujuan = 'Jakarta'
      harga = 890000
    elif nama_tujuan=='MLG' or nama_tujuan=='mlg' or nama_tujuan=='Malang' or nama_tujuan=='malang' or nama_tujuan=='MALANG':
      nama_tujuan = 'Malang'
      harga = 88000
    elif nama_tujuan=='SOC' or nama_tujuan=='soc' or nama_tujuan=='Solo' or nama_tujuan=='solo' or nama_tujuan=='SOLO':
      nama_tujuan = 'Solo'
      harga = 450000
    elif nama_tujuan=='KD' or nama_tujuan=='kd' or nama_tujuan=='Kediri' or nama_tujuan=='kediri' or nama_tujuan=='KEDIRI':
      nama_tujuan = 'Kediri'
      harga = 100000 
    elif nama_tujuan=='BWI' or nama_tujuan=='bwi' or nama_tujuan=='Banyuwangi' or nama_tujuan=='banyuwangi' or nama_tujuan=='BANYUWANGI':
      nama_tujuan = 'Banyuwangi'
      harga = 560000
    elif nama_tujuan=='BL' or nama_tujuan=='bl' or nama_tujuan=='Bali' or nama_tujuan=='bali' or nama_tujuan=='BALI':
      nama_tujuan = 'Bali'
      harga = 990000
    elif nama_tujuan=='BR' or nama_tujuan=='br' or nama_tujuan=='Blitar' or nama_tujuan=='blitar' or nama_tujuan=='BLITAR':
      nama_tujuan = 'Blitar'
      harga = 300000
    elif nama_tujuan=='BDG' or nama_tujuan=='bdg' or nama_tujuan=='Bandung' or nama_tujuan=='bandung' or nama_tujuan=='BANDUNG':
      nama_tujuan = 'Bandung'
      harga = 780000
    elif nama_tujuan=='MN' or nama_tujuan=='mn' or nama_tujuan=='Madiun' or nama_tujuan=='madiun' or nama_tujuan=='MADIUN':
      nama_tujuan = 'Madiun'
      harga = 100000  

    # Output Struk Pembelian Tiket
    print('-' * 81)      
    print('                       STRUK PEMBELIAN TIKET BUS')      
    print('-' * 81)
    print('Nama Pembeli            : ', str(pembeli))
    print('No. Handphone           : ', str(no_hp))
    print('Tujuan Keberangkatan    : Surabaya -> ', str(nama_tujuan))
    print('Tanggal Keberangkatan   : {} Desember 2022'.format(tgl_berangkat))
    print('Harga Tiket             : Rp.{:,.0f},-'.format(harga))
    print('Jumlah Tiket            : ', str(jml_tiket))
    print('No. Kursi               : ', random.sample(range(1,31), jml_tiket))
      
    # Proses Diskon Jika Tiket yang Dibeli Lebih dari 3
    if jml_tiket > 3:
      harga_dengan_diskon = jml_tiket*harga
      diskon = (jml_tiket*harga)*0.2
      total = (jml_tiket*harga)-diskon
      
      # Output Struk Jika Mendapatkan Diskon
      print('-' * 81)
      print('                       PROMO AKHIR TAHUN 20%      ')
      print('-' * 81)
      print('Harga                 : Rp.{:,.0f},-'.format(harga_dengan_diskon))
      print('Diskon yang Didapat   : Rp.{:,.0f},-'.format(diskon))
      print('Total Bayar           : Rp.{:,.0f},-'.format(total))
      print('-' * 81)

    else: 
      diskon = 0
      harga_dengan_diskon = jml_tiket*harga
      total = (jml_tiket*harga)-diskon

    # Menu Pembayaran Tiket
    pembayaran = int(input('Masukkan Uang Pembayaran: '))
    kembalian = pembayaran-total
    print('-' * 81)

    # Output Kembalian
    print('Kembalian Anda         : Rp.{:,.0f},-'.format(kembalian))
    print('-' * 81)

    # Proses Pengulangan Transaksi
    transaksi = input('Apakah Ingin Kembali ke Menu? [Y/N]: ')
    if transaksi == 'y' or transaksi=='Y':
      transaksi='Y'
      print('\n')
    else:
      transaksi='N'
      print('-' * 81)
      print('Terima Kasih Telah Mengunjungi Aplikasi Kami ^.^')
      break

  # Apabila Memilih Menu Nomor 3
  elif menu == "3": 
    print("\nPanduan refund tiket bus: ")
    print("1. Isi formulir pembatalan disertai keterangan pembatalan tiket")
    print("2. Sertakan bukti transaksi")
    print("3. Serahkan kepada petugas loket yang tersedia")
    print("")
    print("Terimakasih!")
    print('-' * 81)
  
  # Apabila Memilih Menu Nomor 4
  elif menu=="4":
    print("\nMohon hubungi kontak kami apabila ada kendala dan meminta bantuan.")
    listCS = ["(0271)714039", "121 / (021)121", "09.00-16.00"]
    print("Office phone : ", listCS[0])
    print("Contact center : ", listCS[1])
    print("Jam pelayanan : ", listCS[2])
    print("")
    print("Terima kasih")
    print('-' * 81)

  # Memilih Menu Selain 1-3
  else:
    print("Menu tidak valid, pilih menu 1-3!")
    ulang=input("Kembali ke menu [y/n]: ")
    if ulang=='y' or ulang=='Y':
        continue
    else:
      transaksi='N'
      print('-' * 81)
      print('Terima Kasih Telah Mengunjungi Aplikasi Kami ^.^')
